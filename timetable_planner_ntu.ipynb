# %% [markdown]
# # Timetable Planner NTU
# *Wai Yan Min Ko Ko*
#
# The reason for creating this notebook is to make it easy for me to plan out my schedule for the next semester.
#
# Columns: Course Code, Course Name, Index, Type, Group, Day, Time, Venue, Remark
#
# To take note:
# - Type has these variables: Lec/Studio, ONLINE, Tut, Lab

# %% [markdown]
# ## Features
#
# ### General
# - Check unique modules inside the file
#
# ### Per Module
# - Check the indexes that fit the requirements (day, time)
#
# ### Per Day
# - Check indexes that fit the requirement in the day, time
#
# ### All 5 Days
# - Select which days I want to go for tutorials and labs, while lectures are an exception.
# - Select the timing for each day.

# %% [markdown]
# ## Import Python Libraries
# - pandas
# - numpy
# - ipywidgets
# - IPython.display

# %%
import pandas as pd
import numpy as np

# User Interactive Libraries
import ipywidgets as widgets  # Used for creating interactive HTML widgets for Jupyter notebooks and IPython
from ipywidgets import interact  # Used for creating interactive user interfaces in Jupyter notebooks
from IPython.display import display  # Used for displaying widgets and other outputs in Jupyter notebooks

# %% [markdown]
# ## Import CSV File
#
# CSV file located in the same folder as the notebook.

# %%
# Read the data from the CSV file
data = pd.read_csv('y1s2_all_mods_schedule.csv')

# Convert the 'Index' column to integer type
data['Index'] = data['Index'].astype('Int64')

# Display the first few rows of the dataframe to verify the change
data.head()
# Out:
#   Course Code                                        Course Name  Index Type  \
# 0      CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82201  Tut
# 1      CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82202  Tut
# 2      CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82203  Tut
# 3      CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82204  Tut
# 4      CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82205  Tut
#
#   Group  Day        Time      Venue           Remark
# 0  T001  Mon  1030to1220  LHN-TR+22  Teaching Wk2-13
# 1  T002  Mon  1030to1220  LHN-TR+23  Teaching Wk2-13
# 2  T003  Mon  1030to1220  LHN-TR+24  Teaching Wk2-13
# 3  T004  Mon  1030to1220  LHN-TR+25  Teaching Wk2-13
# 4  T005  Mon  1030to1220  LHN-TR+33  Teaching Wk2-13

# %% [markdown]
# ## Import CSV File from Github Repository

# %%
import io

import requests # Used for sending HTTP requests to the web and receiving responses

# Step 1: Download the CSV data
url = 'https://github.com/waiyanminkoko/timetable_planner_ntu/blob/ff22800cfac74d54f206b05d9b855608afd0293d/y1s2_all_mods_schedule.csv?raw=true'
response = requests.get(url)

if response.status_code == 200:
  data = pd.read_csv(io.StringIO(response.content.decode('utf-8')))

  # Convert the 'Index' column to integer type
  data['Index'] = data['Index'].astype('Int64')

  # Display the first few rows of the dataframe to verify the change
  print(data)
else:
  print("Error downloading file.")
  # Read the CSV data into a pandas DataFrame
# Out:
#     Course Code                                        Course Name  Index  \
# 0        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82201
# 1        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82202
# 2        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82203
# 3        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82204
# 4        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINAR...  82205
# ..          ...                                                ...    ...
# 659      SC2000             PROBABILITY & STATISTICS FOR COMPUTING  10140
# 660      SC2000             PROBABILITY & STATISTICS FOR COMPUTING  10140
# 661      SC2000             PROBABILITY & STATISTICS FOR COMPUTING  10141
# 662      SC2000             PROBABILITY & STATISTICS FOR COMPUTING  10141
# 663      SC2000             PROBABILITY & STATISTICS FOR COMPUTING  10141
#
#            Type Group  Day        Time      Venue           Remark
# 0           Tut  T001  Mon  1030to1220  LHN-TR+22  Teaching Wk2-13
# 1           Tut  T002  Mon  1030to1220  LHN-TR+23  Teaching Wk2-13
# 2           Tut  T003  Mon  1030to1220  LHN-TR+24  Teaching Wk2-13
# 3           Tut  T004  Mon  1030to1220  LHN-TR+25  Teaching Wk2-13
# 4           Tut  T005  Mon  1030to1220  LHN-TR+33  Teaching Wk2-13
# ..          ...   ...  ...         ...        ...              ...
# 659  Lec/Studio  SCL2  Tue  1630to1720       LT2A  Teaching Wk1-13
# 660         Tut  SDDA  Wed  1130to1220      TR+18  Teaching Wk2-13
# 661  Lec/Studio  SCL2  Fri  1630to1720       LT2A  Teaching Wk1-13
# 662  Lec/Studio  SCL2  Tue  1630to1720       LT2A  Teaching Wk1-13
# 663         Tut  SDDB  Mon  1230to1320      TR+23  Teaching Wk2-13
#
# [664 rows x 9 columns]

# %% [markdown]
# ## General
# - Check unique modules inside the file

# %%
pd.set_option('display.max_colwidth', None)

unique_courses = data[['Course Code', 'Course Name']].drop_duplicates()
print(unique_courses)
# Out:
#     Course Code                                            Course Name
# 0        CC0001  INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
# 180      CC0002                           NAVIGATING THE DIGITAL WORLD
# 246      MH1812                                   DISCRETE MATHEMATICS
# 274      SC1006                   COMPUTER ORGANISATION & ARCHITECTURE
# 382      SC1007                           DATA STRUCTURES & ALGORITHMS
# 496      SC1008                                    C & C++ PROGRAMMING
# 583      SC2000                 PROBABILITY & STATISTICS FOR COMPUTING

# %% [markdown]
# ## Per Module
# - Check the indexes that fit the requirements (day, time)

# %%
# Create dropdown for course code
course_code_dropdown = widgets.Dropdown(
    options=unique_courses['Course Code'].unique(),
    description='Course Code:',
    disabled=False,
)

# Create dropdown for day
day_dropdown = widgets.Dropdown(
    options=data['Day'].unique(),
    description='Day:',
    disabled=False,
)

# Create time pickers for start and end time
start_time_picker = widgets.Text(
    #value='0000',
    description='Start Time:',
    placeholder='e.g., 1030',
)

end_time_picker = widgets.Text(
    #value='2359',
    description='End Time:',
    placeholder='e.g., 1800',
)

# Display the widgets
display(course_code_dropdown, day_dropdown, start_time_picker, end_time_picker)
# Out:
# Dropdown(description='Course Code:', options=('CC0001', 'CC0002', 'MH1812', 'SC1006', 'SC1007', 'SC1008', 'SC2…
# Dropdown(description='Day:', options=('Mon', 'Tue', 'Wed', 'Thu', 'Fri'), value='Mon')
# Text(value='', description='Start Time:', placeholder='e.g., 1030')
# Text(value='', description='End Time:', placeholder='e.g., 1800')

# %%
def filter_data(course_code, day, start_time, end_time):
    filtered_data = data[
        (data['Course Code'] == course_code) &
        (data['Day'] == day) &
        (data['Time'].str[:4] >= start_time) &
        (data['Time'].str[-4:] <= end_time)
    ]
    return filtered_data

# Get the selected values from the widgets
selected_course_code = course_code_dropdown.value
selected_day = day_dropdown.value
selected_start_time = start_time_picker.value
selected_end_time = end_time_picker.value

# Filter the data
filtered_data = filter_data(selected_course_code, selected_day, selected_start_time, selected_end_time)

# Get the course name
course_name = unique_courses[unique_courses['Course Code'] == selected_course_code]['Course Name'].values[0]

# Display the filtered data with title
print(f"Course Code: {selected_course_code} - Course Name: {course_name}")
print(filtered_data.drop(columns=['Course Code', 'Course Name']))

# Save the filtered data to a CSV file
filtered_data.to_csv('course.csv', index=False)
# Out:
# Course Code: CC0001 - Course Name: INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
#     Index Type Group  Day        Time      Venue           Remark
# 0   82201  Tut  T001  Mon  1030to1220  LHN-TR+22  Teaching Wk2-13
# 1   82202  Tut  T002  Mon  1030to1220  LHN-TR+23  Teaching Wk2-13
# 2   82203  Tut  T003  Mon  1030to1220  LHN-TR+24  Teaching Wk2-13
# 3   82204  Tut  T004  Mon  1030to1220  LHN-TR+25  Teaching Wk2-13
# 4   82205  Tut  T005  Mon  1030to1220  LHN-TR+33  Teaching Wk2-13
# 5   82206  Tut  T006  Mon  1030to1220  LHN-TR+27  Teaching Wk2-13
# 6   82207  Tut  T007  Mon  1030to1220  LHN-TR+28  Teaching Wk2-13
# 7   82208  Tut  T008  Mon  1030to1220  LHN-TR+29  Teaching Wk2-13
# 8   82209  Tut  T009  Mon  1030to1220  LHN-TR+32  Teaching Wk2-13
# 9   82210  Tut  T010  Mon  1030to1220  LHN-TR+13  Teaching Wk2-13
# 10  82211  Tut  T011  Mon  1230to1420  LHN-TR+22  Teaching Wk2-13
# 11  82212  Tut  T012  Mon  1230to1420  LHN-TR+23  Teaching Wk2-13
# 12  82213  Tut  T013  Mon  1230to1420  LHN-TR+24  Teaching Wk2-13
# 13  82214  Tut  T014  Mon  1230to1420  LHN-TR+25  Teaching Wk2-13
# 14  82215  Tut  T015  Mon  1230to1420  LHN-TR+26  Teaching Wk2-13
# 15  82216  Tut  T016  Mon  1230to1420  LHN-TR+27  Teaching Wk2-13
# 16  82217  Tut  T017  Mon  1230to1420  LHN-TR+28  Teaching Wk2-13
# 17  82218  Tut  T018  Mon  1230to1420  LHN-TR+29  Teaching Wk2-13
# 18  82219  Tut  T019  Mon  1230to1420  LHN-TR+32  Teaching Wk2-13
# 19  82220  Tut  T020  Mon  1230to1420  LHN-TR+13  Teaching Wk2-13
# 20  82221  Tut  T021  Mon  1430to1620  LHN-TR+22  Teaching Wk2-13
# 21  82222  Tut  T022  Mon  1430to1620  LHN-TR+23  Teaching Wk2-13
# 22  82223  Tut  T023  Mon  1430to1620  LHN-TR+24  Teaching Wk2-13
# 23  82224  Tut  T024  Mon  1430to1620  LHN-TR+25  Teaching Wk2-13
# 24  82225  Tut  T025  Mon  1430to1620  LHN-TR+26  Teaching Wk2-13
# 25  82226  Tut  T026  Mon  1430to1620  LHN-TR+27  Teaching Wk2-13
# 26  82227  Tut  T027  Mon  1430to1620  LHN-TR+28  Teaching Wk2-13
# 27  82228  Tut  T028  Mon  1430to1620  LHN-TR+29  Teaching Wk2-13
# 28  82229  Tut  T029  Mon  1430to1620  LHN-TR+32  Teaching Wk2-13
# 29  82230  Tut  T030  Mon  1430to1620  LHN-TR+13  Teaching Wk2-13

# %% [markdown]
# ## Per Day
# - Check indexes that fit the requirement in the day, time

# %%
# Create dropdown for day
day_dropdown = widgets.Dropdown(
    options=data['Day'].unique(),
    description='Day:',
    disabled=False,
)

# Create time pickers for start and end time
start_time_picker = widgets.Text(
    value='1000',
    description='Start Time:',
    placeholder='e.g., 1030',
)

end_time_picker = widgets.Text(
    value='1800',
    description='End Time:',
    placeholder='e.g., 1800',
)

# Display the widgets
display(day_dropdown, start_time_picker, end_time_picker)
# Out:
# Dropdown(description='Day:', options=('Mon', 'Tue', 'Wed', 'Thu', 'Fri'), value='Mon')
# Text(value='1000', description='Start Time:', placeholder='e.g., 1030')
# Text(value='1800', description='End Time:', placeholder='e.g., 1800')

# %%
def filter_data_by_day_time(day, start_time, end_time):
    filtered_data = data[
        (data['Day'] == day) &
        (data['Time'].str[:4] >= start_time) &
        (data['Time'].str[-4:] <= end_time)
    ]
    return filtered_data

# Filter the data
filtered_data_by_day_time = filter_data_by_day_time(selected_day, selected_start_time, selected_end_time)

# Display the title
print(f"Day: {selected_day} - Start Time: {selected_start_time} - End Time: {selected_end_time}")

# Display the filtered data with course code and course name as the title
for course_code in filtered_data_by_day_time['Course Code'].unique():
    course_name = unique_courses[unique_courses['Course Code'] == course_code]['Course Name'].values[0]
    print(f"\nCourse Code: {course_code} - Course Name: {course_name}")
    print(filtered_data_by_day_time[filtered_data_by_day_time['Course Code'] == course_code].drop(columns=['Course Code', 'Course Name', 'Day', 'Time']))

# Save the filtered data to a CSV file
filtered_data_by_day_time.to_csv('day_time.csv', index=False)
# Out:
# Day: Mon - Start Time: 1000 - End Time: 1800
#
# Course Code: CC0001 - Course Name: INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
#     Index Type Group      Venue           Remark
# 0   82201  Tut  T001  LHN-TR+22  Teaching Wk2-13
# 1   82202  Tut  T002  LHN-TR+23  Teaching Wk2-13
# 2   82203  Tut  T003  LHN-TR+24  Teaching Wk2-13
# 3   82204  Tut  T004  LHN-TR+25  Teaching Wk2-13
# 4   82205  Tut  T005  LHN-TR+33  Teaching Wk2-13
# 5   82206  Tut  T006  LHN-TR+27  Teaching Wk2-13
# 6   82207  Tut  T007  LHN-TR+28  Teaching Wk2-13
# 7   82208  Tut  T008  LHN-TR+29  Teaching Wk2-13
# 8   82209  Tut  T009  LHN-TR+32  Teaching Wk2-13
# 9   82210  Tut  T010  LHN-TR+13  Teaching Wk2-13
# 10  82211  Tut  T011  LHN-TR+22  Teaching Wk2-13
# 11  82212  Tut  T012  LHN-TR+23  Teaching Wk2-13
# 12  82213  Tut  T013  LHN-TR+24  Teaching Wk2-13
# 13  82214  Tut  T014  LHN-TR+25  Teaching Wk2-13
# 14  82215  Tut  T015  LHN-TR+26  Teaching Wk2-13
# 15  82216  Tut  T016  LHN-TR+27  Teaching Wk2-13
Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 359  10044  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 361  10044         Lab  FCS5  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 363  10045  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 367  10046  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 371  10047  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 375  10048  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
# 376  10048         Tut  MACS    TR+6             Teaching Wk2-13
# 379  10998  Lec/Studio  SCL1    LT1A             Teaching Wk1-13
#
# Course Code: SC1007 - Course Name: DATA STRUCTURES & ALGORITHMS
#      Index Type Group   Venue           Remark
# 387  10050  Lab  FCEB  HWLAB2  Teaching Wk2-13
# 389  10051  Tut  FCEC    TR+1  Teaching Wk2-13
# 396  10053  Lab  FCE1  HWLAB2  Teaching Wk2-13
# 399  10054  Lab  FCE2  SWLAB2  Teaching Wk2-13
# 401  10055  Tut  FCE3    TR+3  Teaching Wk2-13
# 414  10059  Lab  FCSD  HWLAB2  Teaching Wk2-13
# 416  10060  Tut  FCSE    TR+1  Teaching Wk2-13
# 431  10065  Tut  FCSJ    TR+3  Teaching Wk2-13
# 453  10072  Lab  FCMA  HWLAB1  Teaching Wk2-13
# 465  10076  Lab  FDAB  SWLAB2  Teaching Wk2-13
# 471  10078  Lab  FDAD  HWLAB2  Teaching Wk2-13
# 488  10084  Tut  BACF   TR+23  Teaching Wk2-13
# 489  10084  Lab  BACF  HWLAB2  Teaching Wk2-13
#
# Course Code: SC1008 - Course Name: C & C++ PROGRAMMING
#      Index Type Group   Venue           Remark
# 506  10090  Tut  FCED     SPL  Teaching Wk2-13
# 507  10090  Lab  FCED     SPL  Teaching Wk2-13
# 524  10096  Tut  FCSC     SPL  Teaching Wk2-13
# 525  10096  Lab  FCSC     SPL  Teaching Wk2-13
# 545  10103  Tut  FCSJ  SWLAB1  Teaching Wk2-13
# 546  10103  Lab  FCSJ  SWLAB1  Teaching Wk2-13
# 566  10110  Tut  FCMA     SPL  Teaching Wk2-13
# 567  10110  Lab  FCMA     SPL  Teaching Wk2-13
# 572  10112  Tut  FCMC     HPL  Teaching Wk2-13
# 573  10112  Lab  FCMC     HPL  Teaching Wk2-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index Type Group  Venue           Remark
# 585  10115  Tut  FCEA   TR+8  Teaching Wk2-13
# 603  10121  Tut  FCE3   TR+3  Teaching Wk2-13
# 630  10130  Tut  FCSI   TR+6  Teaching Wk2-13
# 651  10137  Tut  FCS6   TR+5  Teaching Wk2-13
# 663  10141  Tut  SDDB  TR+23  Teaching Wk2-13

# %% [markdown]
# ## All 5 Days
# - Select which days I want to go for tutorials and labs, while lectures are an exception.
# - Select the timing for each day.

# %%
# Create a list of days
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

# Create a dictionary to store the time pickers for each day
time_pickers = {}

# Create checkboxes for each day
day_checkboxes = {day: widgets.Checkbox(value=False, description=day) for day in days}

# Create time pickers for each day
for day in days:
    start_time_picker = widgets.Text(
        value='0800',
        description=f'{day} Start Time:',
        placeholder='e.g., 0800',
        layout=widgets.Layout(display='none')
    )
    end_time_picker = widgets.Text(
        value='1800',
        description=f'{day} End Time:',
        placeholder='e.g., 1800',
        layout=widgets.Layout(display='none')
    )
    time_pickers[day] = (start_time_picker, end_time_picker)

    # Observe the checkbox value change
    def on_checkbox_change(change, day=day):
        if change['new']:
            time_pickers[day][0].layout.display = 'block'
            time_pickers[day][1].layout.display = 'block'
        else:
            time_pickers[day][0].layout.display = 'none'
            time_pickers[day][1].layout.display = 'none'

    day_checkboxes[day].observe(on_checkbox_change, names='value')

# Display the checkboxes and time pickers
display("Select the days you want to go for labs and tutorials")
for day in days:
    display(day_checkboxes[day], time_pickers[day][0], time_pickers[day][1])
# Out:
# 'Select the days you want to go for labs and tutorials'
# Checkbox(value=False, description='Mon')
# Text(value='0800', description='Mon Start Time:', layout=Layout(display='none'), placeholder='e.g., 0800')
# Text(value='1800', description='Mon End Time:', layout=Layout(display='none'), placeholder='e.g., 1800')
# Checkbox(value=False, description='Tue')
# Text(value='0800', description='Tue Start Time:', layout=Layout(display='none'), placeholder='e.g., 0800')
# Text(value='1800', description='Tue End Time:', layout=Layout(display='none'), placeholder='e.g., 1800')
# Checkbox(value=False, description='Wed')
# Text(value='0800', description='Wed Start Time:', layout=Layout(display='none'), placeholder='e.g., 0800')
# Text(value='1800', description='Wed End Time:', layout=Layout(display='none'), placeholder='e.g., 1800')
# Checkbox(value=False, description='Thu')
# Text(value='0800', description='Thu Start Time:', layout=Layout(display='none'), placeholder='e.g., 0800')
# Text(value='1800', description='Thu End Time:', layout=Layout(display='none'), placeholder='e.g., 1800')
# Checkbox(value=False, description='Fri')
# Text(value='0800', description='Fri Start Time:', layout=Layout(display='none'), placeholder='e.g., 0800')
# Text(value='1800', description='Fri End Time:', layout=Layout(display='none'), placeholder='e.g., 1800')

# %%
def filter_courses_by_day_time(day, start_time, end_time):
    filtered_data = data[
        (data['Day'] == day) &
        (data['Time'].str[:4] >= start_time) &
        (data['Time'].str[-4:] <= end_time)
    ]
    return filtered_data

# Iterate through the selected days and filter the data
for day in days:
    if day_checkboxes[day].value:
        start_time = time_pickers[day][0].value
        end_time = time_pickers[day][1].value
        filtered_courses = filter_courses_by_day_time(day, start_time, end_time)
        
        # Display the title
        print(f"Day: {day} - Start Time: {start_time} - End Time: {end_time}")
        
        # Display the filtered data with course code and course name as the title
        for course_code in filtered_courses['Course Code'].unique():
            course_name = unique_courses[unique_courses['Course Code'] == course_code]['Course Name'].values[0]
            print(f"\nCourse Code: {course_code} - Course Name: {course_name}")
            print(filtered_courses[filtered_courses['Course Code'] == course_code].drop(columns=['Course Code', 'Course Name', 'Day']))
        #print a dot line to separate the output by days
        print("\n" + "-"*100 + "\n")
        # Filter and display courses that are not "Lab" or "Tut" and do not fall into the selected days
        non_tut_lab_courses = data[
            (~data['Type'].isin(['Lab', 'Tut'])) &
            (~data['Day'].isin([day for day in days if day_checkboxes[day].value]))
        ]

        if not non_tut_lab_courses.empty:
            print("Courses that are not 'Lab' or 'Tut' and do not fall into the selected days:")
            for course_code in non_tut_lab_courses['Course Code'].unique():
                course_name = unique_courses[unique_courses['Course Code'] == course_code]['Course Name'].values[0]
                print(f"\nCourse Code: {course_code} - Course Name: {course_name}")
                print(non_tut_lab_courses[non_tut_lab_courses['Course Code'] == course_code].drop(columns=['Course Code', 'Course Name']))
            print("\n" + "-"*100 + "\n")
            # Combine filtered_courses and non_tut_lab_courses into one DataFrame
            combined_courses = pd.concat([filtered_courses, non_tut_lab_courses])

        # Save the combined data to a CSV file
        combined_courses.to_csv('day_time_all.csv', index=False)
# Out:
# Day: Tue - Start Time: 0800 - End Time: 1800
#
# Course Code: CC0001 - Course Name: INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
#     Index Type Group        Time      Venue           Remark
# 38  82239  Tut  T039  1030to1220  LHN-TR+22  Teaching Wk2-13
# 39  82240  Tut  T040  1030to1220  LHN-TR+23  Teaching Wk2-13
# 40  82241  Tut  T041  1030to1220  LHN-TR+24  Teaching Wk2-13
# 41  82242  Tut  T042  1030to1220  LHN-TR+25  Teaching Wk2-13
# 42  82243  Tut  T043  1030to1220  LHN-TR+26  Teaching Wk2-13
# 43  82244  Tut  T044  1030to1220  LHN-TR+27  Teaching Wk2-13
# 44  82245  Tut  T045  1030to1220  LHN-TR+28  Teaching Wk2-13
# 45  82246  Tut  T046  1030to1220  LHN-TR+29  Teaching Wk2-13
# 46  82247  Tut  T047  1030to1220  LHN-TR+32  Teaching Wk2-13
# 47  82248  Tut  T048  1030to1220  LHN-TR+13  Teaching Wk2-13
# 48  82249  Tut  T049  1230to1420  LHN-TR+22  Teaching Wk2-13
# 49  82250  Tut  T050  1230to1420  LHN-TR+23  Teaching Wk2-13
# 50  82251  Tut  T051  1230to1420  LHN-TR+24  Teaching Wk2-13
# 51  82252  Tut  T052  1230to1420  LHN-TR+25  Teaching Wk2-13
# 52  82253  Tut  T053  1230to1420  LHN-TR+34  Teaching Wk2-13
# 53  82254  Tut  T054  1230to1420  LHN-TR+27  Teaching Wk2-13
# 54  82255  Tut  T055  1230to1420  LHN-TR+28  Teaching Wk2-13
# 55  82256  Tut  T056  1230to1420  LHN-TR+29  Teaching Wk2-13
# 56  82257  Tut  T057  1230to1420  LHN-TR+32  Teaching Wk2-13
# 57  82258  Tut  T058  1230to1420  LHN-TR+13  Teaching Wk2-13
# 58  82259  Tut  T059  1430to1620  LHN-TR+22  Teaching Wk2-13
# 59  82260  Tut  T060  1430to1620  LHN-TR+23  Teaching Wk2-13
# 60  82261  Tut  T061  1430to1620  LHN-TR+24  Teaching Wk2-13
# 61  82262  Tut  T062  1430to1620  LHN-TR+25  Teaching Wk2-13
# 62  82263  Tut  T063  1430to1620  LHN-TR+26  Teaching Wk2-13
# 63  82264  Tut  T064  1430to1620  LHN-TR+27  Teaching Wk2-13
# 64  82265  Tut  T065  1430to1620  LHN-TR+28  Teaching Wk2-13
# 65  82266  Tut  T066  1430to1620  LHN-TR+29  Teaching Wk2-13
# 66  82267  Tut  T067  1430to1620  LHN-TR+32  Teaching Wk2-13
# 67  82268  Tut  T068  1430to1620  LHN-TR+13  Teaching Wk2-13
#
# Course Code: CC0002 - Course Name: NAVIGATING THE DIGITAL WORLD
#      Index Type Group        Time      Venue           Remark
# 195  82415  Tut  T016  1030to1220  LHN-TR+52  Teaching Wk2-13
# 196  82416  Tut  T017  1030to1220  LHN-TR+30  Teaching Wk2-13
# 197  82417  Tut  T018  1030to1220  LHN-TR+36  Teaching Wk2-13
# 198  82418  Tut  T019  1030to1220  LHN-TR+37  Teaching Wk2-13
# 199  82419  Tut  T020  1230to1420  LHN-TR+52  Teaching Wk2-13
# 200  82420  Tut  T021  1230to1420  LHN-TR+30  Teaching Wk2-13
# 201  82421  Tut  T022  1230to1420  LHN-TR+36  Teaching Wk2-13
# 202  82422  Tut  T023  1230to1420  LHN-TR+37  Teaching Wk2-13
# 203  82423  Tut  T024  1430to1620  LHN-TR+52  Teaching Wk2-13
# 204  82424  Tut  T025  1430to1620  LHN-TR+30  Teaching Wk2-13
# 205  82425  Tut  T026  1430to1620  LHN-TR+36  Teaching Wk2-13
# 206  82426  Tut  T027  1430to1620  LHN-TR+37  Teaching Wk2-13
#
# Course Code: MH1812 - Course Name: DISCRETE MATHEMATICS
#      Index Type Group        Time Venue           Remark
# 269  10194  Tut   FR2  0930to1020  TR+9  Teaching Wk2-13
#
# Course Code: SC1006 - Course Name: COMPUTER ORGANISATION & ARCHITECTURE
#      Index Type  Group        Time   Venue                      Remark
# 281  10024  Lab   FCEB  0830to1020  HWLAB2    Teaching Wk2,4,6,8,10,12
# 285  10025  Lab   FCEC  0830to1020  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 288   <NA>  Tut   FCED  0930to1020   TR+17             Teaching Wk2-13
# 293  10027  Lab   FCE1  0830to1020  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 297  10028  Lab   FCE2  0830to1020  HWLAB2    Teaching Wk2,4,6,8,10,12
# 300  10029  Tut   FCE3  1330to1420    TR+5             Teaching Wk2-13
# 304  10030  Tut   FCSA  1230to1320    TR+3             Teaching Wk2-13
# 340  10039  Tut   FCSJ  0930to1020    TR+2             Teaching Wk2-13
# 352  10042  Tut   FCS3  1230to1320    TR+4             Teaching Wk2-13
# 372  10047  Tut   FCMC  1630to1720    TR+3             Teaching Wk2-13
# 380  10998  Tut  TAISP  1630to1720    TR+7             Teaching Wk2-13
#
# Course Code: SC1007 - Course Name: DATA STRUCTURES & ALGORITHMS
#      Index        Type Group        Time   Venue           Remark
# 382  10049  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 385  10050  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 388  10051  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 391  10052  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 393  10052         Lab  FCED  1030to1220  SWLAB2  Teaching Wk2-13
# 394  10053  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 397  10054  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 400  10055  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 403  10056  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 406  10057  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 408  10057         Lab  FCSB  1230to1420  SWLAB2  Teaching Wk2-13
# 409  10058  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 410  10058         Tut  FCSC  0930to1020    TR+3  Teaching Wk2-13
# 412  10059  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 413  10059         Tut  FCSD  0930to1020    TR+4  Teaching Wk2-13
# 415  10060  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 418  10061  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 420  10061         Lab  FCSF  0830to1020  HWLAB2  Teaching Wk2-13
# 421  10062  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 424  10063  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
# 427  10064  Lec/Studio  SCL1  1430to1620  LKC-LT  Teaching Wk1-13
#
Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
#
# Course Code: SC1006 - Course Name: COMPUTER ORGANISATION & ARCHITECTURE
#      Index        Type Group  Day        Time Venue           Remark
# 275  10023  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 279  10024  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 283  10025  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 287  10026  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 291  10027  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 295  10028  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 299  10029  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 303  10030  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 307  10031  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 311  10032  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 315  10033  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 319  10034  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 323  10035  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 327  10036  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 331  10037  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 335  10038  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 339  10039  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 343  10040  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 347  10041  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 351  10042  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 355  10043  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 359  10044  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 363  10045  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 367  10046  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 371  10047  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 375  10048  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 379  10998  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index        Type Group  Day        Time Venue           Remark
# 583  10115  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 586  10116  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 589  10117  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 592  10118  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 595  10119  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 598  10120  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 601  10121  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 604  10122  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 607  10123  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 610  10124  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 613  10125  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 616  10126  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 619  10127  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 622  10128  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 625  10129  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 628  10130  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 631  10131  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 634  10132  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 637  10133  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 640  10134  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 643  10135  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 646  10136  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 649  10137  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 652  10138  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 655  10139  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 658  10140  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 661  10141  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
#
# ----------------------------------------------------------------------------------------------------
#
# Day: Wed - Start Time: 0800 - End Time: 1800
#
# Course Code: CC0001 - Course Name: INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
#      Index Type Group        Time      Venue           Remark
# 76   82277  Tut  T077  1030to1220  LHN-TR+22  Teaching Wk2-13
# 77   82278  Tut  T078  1030to1220  LHN-TR+23  Teaching Wk2-13
# 78   82279  Tut  T079  1030to1220  LHN-TR+24  Teaching Wk2-13
# 79   82280  Tut  T080  1030to1220  LHN-TR+25  Teaching Wk2-13
# 80   82281  Tut  T081  1030to1220  LHN-TR+26  Teaching Wk2-13
# 81   82282  Tut  T082  1030to1220  LHN-TR+27  Teaching Wk2-13
# 82   82283  Tut  T083  1030to1220  LHN-TR+28  Teaching Wk2-13
# 83   82284  Tut  T084  1030to1220  LHN-TR+29  Teaching Wk2-13
# 84   82285  Tut  T085  1030to1220  LHN-TR+32  Teaching Wk2-13
# 85   82286  Tut  T086  1030to1220  LHN-TR+13  Teaching Wk2-13
# 86   82287  Tut  T087  1230to1420  LHN-TR+22  Teaching Wk2-13
# 87   82288  Tut  T088  1230to1420  LHN-TR+23  Teaching Wk2-13
# 88   82289  Tut  T089  1230to1420  LHN-TR+24  Teaching Wk2-13
# 89   82290  Tut  T090  1230to1420  LHN-TR+25  Teaching Wk2-13
# 90   82291  Tut  T091  1230to1420  LHN-TR+26  Teaching Wk2-13
# 91   82292  Tut  T092  1230to1420  LHN-TR+27  Teaching Wk2-13
# 92   82293  Tut  T093  1230to1420  LHN-TR+28  Teaching Wk2-13
# 93   82294  Tut  T094  1230to1420  LHN-TR+29  Teaching Wk2-13
# 94   82295  Tut  T095  1230to1420  LHN-TR+32  Teaching Wk2-13
# 95   82296  Tut  T096  1230to1420  LHN-TR+13  Teaching Wk2-13
# 96   82297  Tut  T097  1430to1620  LHN-TR+22  Teaching Wk2-13
# 97   82298  Tut  T098  1430to1620  LHN-TR+23  Teaching Wk2-13
Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
# 568  10111  Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
# 571  10112  Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
# 574  10113  Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
# 577  10114  Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
# 580  10997  Lec/Studio  SCL1  1630to1720  ONLINE  Teaching Wk1-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index Type Group        Time  Venue           Remark
# 594  10118  Tut  FCED  1330to1420   TR+4  Teaching Wk2-13
# 612  10124  Tut  FCSC  1030to1120   TR+5  Teaching Wk2-13
# 618  10126  Tut  FCSE  1030to1120   TR+6  Teaching Wk2-13
# 621  10127  Tut  FCSF  1330to1420  TR+16  Teaching Wk2-13
# 624  10128  Tut  FCSG  1230to1320   TR+1  Teaching Wk2-13
# 654  10138  Tut  SCMA  1630to1720   TR+7  Teaching Wk2-13
# 657  10139  Tut  SCMB  1030to1120  TR+16  Teaching Wk2-13
# 660  10140  Tut  SDDA  1130to1220  TR+18  Teaching Wk2-13
#
# ----------------------------------------------------------------------------------------------------
#
# Courses that are not 'Lab' or 'Tut' and do not fall into the selected days:
#
# Course Code: MH1812 - Course Name: DISCRETE MATHEMATICS
#      Index        Type Group  Day        Time Venue           Remark
# 246  10183  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk2-13
# 248  10184  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 250  10185  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 252  10186  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 254  10187  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 256  10188  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 258  10189  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 260  10190  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 262  10191  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 264  10192  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 266  10193  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 268  10194  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 270  10195  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 272  10196  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
#
# Course Code: SC1006 - Course Name: COMPUTER ORGANISATION & ARCHITECTURE
#      Index        Type Group  Day        Time Venue           Remark
# 275  10023  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 279  10024  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 283  10025  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 287  10026  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 291  10027  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 295  10028  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 299  10029  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 303  10030  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 307  10031  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 311  10032  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 315  10033  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 319  10034  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 323  10035  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 327  10036  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 331  10037  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 335  10038  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 339  10039  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 343  10040  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 347  10041  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 351  10042  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 355  10043  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 359  10044  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 363  10045  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 367  10046  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 371  10047  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 375  10048  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 379  10998  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index        Type Group  Day        Time Venue           Remark
# 583  10115  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 586  10116  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 589  10117  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 592  10118  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 595  10119  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 598  10120  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 601  10121  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 604  10122  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 607  10123  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 610  10124  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 613  10125  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 616  10126  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 619  10127  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 622  10128  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 625  10129  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 628  10130  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 631  10131  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 634  10132  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 637  10133  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 640  10134  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 643  10135  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 646  10136  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 649  10137  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 652  10138  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 655  10139  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 658  10140  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 661  10141  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
#
# ----------------------------------------------------------------------------------------------------
#
# Day: Thu - Start Time: 0800 - End Time: 1800
#
# Course Code: CC0001 - Course Name: INQUIRY & COMMUNICATION IN AN INTERDISCIPLINARY WORLD
#      Index Type Group        Time      Venue           Remark
# 114  82315  Tut  T115  1030to1220  LHN-TR+22  Teaching Wk2-13
# 115  82316  Tut  T116  1030to1220  LHN-TR+23  Teaching Wk2-13
# 116  82317  Tut  T117  1030to1220  LHN-TR+24  Teaching Wk2-13
# 117  82318  Tut  T118  1030to1220  LHN-TR+25  Teaching Wk2-13
# 118  82319  Tut  T119  1030to1220  LHN-TR+26  Teaching Wk2-13
# 119  82320  Tut  T120  1030to1220  LHN-TR+27  Teaching Wk2-13
# Course Code: MH1812 - Course Name: DISCRETE MATHEMATICS
#      Index Type Group        Time Venue           Remark
# 247  10183  Tut  FCEA  1530to1620  TR+4  Teaching Wk2-13
# 251  10185  Tut  FCEC  1630to1720  TR+3  Teaching Wk2-13
# 259  10189  Tut  FCE3  1030to1120  TR+9  Teaching Wk2-13
#
# Course Code: SC1006 - Course Name: COMPUTER ORGANISATION & ARCHITECTURE
#      Index Type Group        Time   Venue                      Remark
# 280  10024  Tut  FCEB  1230to1320    TR+6             Teaching Wk2-13
# 312  10032  Tut  FCSC  1130to1220    TR+6             Teaching Wk2-13
# 313  10032  Lab  FCSC  1430to1620  HWLAB2    Teaching Wk2,4,6,8,10,12
# 333  10037  Lab  FCSH  1230to1420  HWLAB2    Teaching Wk2,4,6,8,10,12
# 344  10040  Tut  FCS1  1530to1620    TR+8             Teaching Wk2-13
# 349  10041  Lab  FCS2  1430to1620  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 357  10043  Lab  FCS4  1230to1420  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 368  10046  Tut  FCMB  1630to1720    TR+7             Teaching Wk2-13
# 373  10047  Lab  FCMC  1430to1620  HWLAB2  Teaching Wk1,3,5,7,9,11,13
# 377  10048  Lab  MACS  1430to1620  HWLAB2    Teaching Wk2,4,6,8,10,12
#
# Course Code: SC1007 - Course Name: DATA STRUCTURES & ALGORITHMS
#      Index Type Group        Time   Venue           Remark
# 386  10050  Tut  FCEB  1530to1620    TR+1  Teaching Wk2-13
# 392  10052  Tut  FCED  1530to1620    TR+2  Teaching Wk2-13
# 395  10053  Tut  FCE1  1630to1720    TR+1  Teaching Wk2-13
# 402  10055  Lab  FCE3  1230to1420  HWLAB2  Teaching Wk2-13
# 405  10055  Lab  FCSA  1230to1420  SWLAB2  Teaching Wk2-13
# 407  10057  Tut  FCSB  1330to1420    TR+6  Teaching Wk2-13
# 423  10062  Lab  FCSG  1430to1620  HWLAB2  Teaching Wk2-13
# 426  10063  Lab  FCSH  1030to1220  SWLAB2  Teaching Wk2-13
# 434  10066  Tut  FCS1  1030to1120    TR+8  Teaching Wk2-13
# 450  10071  Lab  FCS6  1430to1620  SWLAB2  Teaching Wk2-13
# 458  10074  Tut  FCMC  1630to1720    TR+5  Teaching Wk2-13
# 459  10074  Lab  FCMC  0830to1020  HWLAB2  Teaching Wk2-13
# 462  10075  Lab  FDAA  1030to1220  HWLAB2  Teaching Wk2-13
# 467  10077  Tut  FDAC  1030to1120    TR+2  Teaching Wk2-13
# 479  10081  Tut  FDDA  1230to1320   TR+16  Teaching Wk2-13
# 485  10083  Tut  ACDA  1230to1320    TR+2  Teaching Wk2-13
#
# Course Code: SC1008 - Course Name: C & C++ PROGRAMMING
#      Index Type Group        Time   Venue           Remark
# 497  10087  Tut  FCEA  1230to1320  SWLAB1  Teaching Wk2-13
# 498  10087  Lab  FCEA  1330to1420  SWLAB1  Teaching Wk2-13
# 503  10089  Tut  FCEC  0830to0920     HPL  Teaching Wk2-13
# 504  10089  Lab  FCEC  0930to1020     HPL  Teaching Wk2-13
# 512  10092  Tut  FCE2  0830to0920  SWLAB1  Teaching Wk2-13
# 513  10092  Lab  FCE2  0930to1020  SWLAB1  Teaching Wk2-13
# 521  10095  Tut  FCSB  1030to1120     SPL  Teaching Wk2-13
# 522  10095  Lab  FCSB  1130to1220     SPL  Teaching Wk2-13
# 533  10099  Tut  FCSF  1430to1520     HPL  Teaching Wk2-13
# 534  10099  Lab  FCSF  1530to1620     HPL  Teaching Wk2-13
# 536  10100  Tut  FCSG  1230to1320     HPL  Teaching Wk2-13
# 537  10100  Lab  FCSG  1330to1420     HPL  Teaching Wk2-13
# 551  10105  Tut  FCS2  1030to1120     HPL  Teaching Wk2-13
# 552  10105  Lab  FCS2  1130to1220     HPL  Teaching Wk2-13
# 557  10107  Tut  FCS4  1430to1520     SPL  Teaching Wk2-13
# 558  10107  Lab  FCS4  1530to1620     SPL  Teaching Wk2-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index Type Group        Time Venue           Remark
# 588  10116  Tut  FCEB  1330to1420  TR+2  Teaching Wk2-13
# 591  10117  Tut  FCEC  1530to1620  TR+9  Teaching Wk2-13
# 636  10132  Tut  FCS1  1430to1520  TR+8  Teaching Wk2-13
#
# ----------------------------------------------------------------------------------------------------
#
# Courses that are not 'Lab' or 'Tut' and do not fall into the selected days:
#
# Course Code: MH1812 - Course Name: DISCRETE MATHEMATICS
#      Index        Type Group  Day        Time Venue           Remark
# 246  10183  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk2-13
# 248  10184  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 250  10185  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 252  10186  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 254  10187  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 256  10188  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 258  10189  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 260  10190  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 262  10191  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 264  10192  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 266  10193  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 268  10194  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 270  10195  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
# 272  10196  Lec/Studio  SCL1  Fri  1530to1620   LT1  Teaching Wk1-13
#
# Course Code: SC1006 - Course Name: COMPUTER ORGANISATION & ARCHITECTURE
#      Index        Type Group  Day        Time Venue           Remark
# 275  10023  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 279  10024  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 283  10025  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 287  10026  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 291  10027  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 295  10028  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 299  10029  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 303  10030  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 307  10031  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 311  10032  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 315  10033  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 319  10034  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 323  10035  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 327  10036  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 331  10037  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 335  10038  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 339  10039  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 343  10040  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 347  10041  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 351  10042  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 355  10043  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 359  10044  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 363  10045  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 367  10046  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 371  10047  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 375  10048  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
# 379  10998  Lec/Studio  SCL1  Mon  1330to1420  LT1A  Teaching Wk1-13
#
# Course Code: SC2000 - Course Name: PROBABILITY & STATISTICS FOR COMPUTING
#      Index        Type Group  Day        Time Venue           Remark
# 583  10115  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 586  10116  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 589  10117  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 592  10118  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 595  10119  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 598  10120  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 601  10121  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 604  10122  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 607  10123  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 610  10124  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 613  10125  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 616  10126  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 619  10127  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 622  10128  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 625  10129  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 628  10130  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 631  10131  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 634  10132  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 637  10133  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 640  10134  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 643  10135  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 646  10136  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 649  10137  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 652  10138  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 655  10139  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 658  10140  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
# 661  10141  Lec/Studio  SCL2  Fri  1630to1720  LT2A  Teaching Wk1-13
#
# ----------------------------------------------------------------------------------------------------
